# %%
import pandas as pd

# %%
df = pd.read_excel('his4.xls')

df['Date'] = df['Year'].map(str)  + "-" + df['Month'].map(str)
df2= df.set_index('Date')
df2
# Out:
#         Year  Month      A      B      C      D      E    ABC     DE    ALL
# Date
# 1993-1  1993      1   90.4   81.3   80.7   74.2   58.1   85.5   69.6   84.4
# 1993-2  1993      2   90.5   82.6   81.3   74.9   62.2   86.2   71.3   85.2
# 1993-3  1993      3   90.2   83.9   81.9   75.4   64.6   86.7   72.4   85.7
# 1993-4  1993      4   92.5   85.4   83.7   76.8   66.2   88.5   73.9   87.5
# 1993-5  1993      5   95.9   88.6   85.9   80.5   72.3   91.6   78.2   90.7
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-2  2020      2  413.7  357.2  320.1  315.5  305.6  375.9  313.0  373.4
# 2020-3  2020      3  420.4  360.4  326.3  312.6  311.4  381.1  312.3  378.4
# 2020-4  2020      4  417.5  360.3  325.7  310.2  309.0  379.9  309.9  377.4
# 2020-5  2020      5  428.1  367.3  332.2  317.4  310.6  388.1  315.9  385.7
# 2020-6  2020      6  429.7  367.0  332.1  324.2  315.4  388.3  322.3  386.1
#
# [330 rows x 10 columns]

# %%
cols = cols[-1:] + cols[:-1]
df3 = df3[cols]
df3
# Out:
#      Date  Month      A      B      C      D      E    ABC     DE    ALL
# 1993  NaN      1   90.4   81.3   80.7   74.2   58.1   85.5   69.6   84.4
# 1993  NaN      2   90.5   82.6   81.3   74.9   62.2   86.2   71.3   85.2
# 1993  NaN      3   90.2   83.9   81.9   75.4   64.6   86.7   72.4   85.7
# 1993  NaN      4   92.5   85.4   83.7   76.8   66.2   88.5   73.9   87.5
# 1993  NaN      5   95.9   88.6   85.9   80.5   72.3   91.6   78.2   90.7
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020  NaN      2  413.7  357.2  320.1  315.5  305.6  375.9  313.0  373.4
# 2020  NaN      3  420.4  360.4  326.3  312.6  311.4  381.1  312.3  378.4
# 2020  NaN      4  417.5  360.3  325.7  310.2  309.0  379.9  309.9  377.4
# 2020  NaN      5  428.1  367.3  332.2  317.4  310.6  388.1  315.9  385.7
# 2020  NaN      6  429.7  367.0  332.1  324.2  315.4  388.3  322.3  386.1
#
# [330 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
# display the data 
power_df = df2['A'].copy()

plt.figure(figsize=(20,10))
# all data points
power_df.plot(title='Housing Price', color='blue',label='12') 
plt.show()

# %%
testing_df = 
t_df = df.loc[:, ['Date', 'A']].copy()

plt.figure(figsize=(10,2))
# all data points
t_df.plot(title='Housing Price', color='blue',label='12') 
plt.show()

plt.show()

# %%
import matplotlib.pyplot as plt
# display the data 
A_df = df1['A'].copy()
B_df = df1['B'].copy()

plt.figure(figsize=(20,10))

# all data points
plt.title("Housing", fontsize=16, fontweight='bold')
plt.plot(A_df, label="X") 
plt.plot(B_df, label="X") 
plt.xlabel("Year")

plt.show()

# %%
df1 = pd.read_excel('his4.xls',index_col=0)
df2 = pd.read_excel('his4.xls',index_col=0)

df['Date'] = df['Year'].map(str)  + "-" + df['Month'].map(str) + "-01 00:00:00"

df3 = df2.join(df['Date'])

cols = df3.columns.tolist()
df1
